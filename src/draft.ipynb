# %%
from dotenv import load_dotenv
import os
import requests
load_dotenv()
# Out:
# True

# %%
import spotipy

# %%
spotify_id = os.getenv('id')
spotify_secret = os.getenv('secret')

# %%
body_params = {"grant_type":"client_credentials"}

url = "https://accounts.spotify.com/api/token"

response = requests.post(url, data=body_params, auth=(spotify_id,spotify_secret))

# %%
def spotifyToken ():
    """This function refreshes a token for a given app on Spotify
    returns: token as a string
    """

    # 1. Defining: credentials fot the app
    CLIENT_ID = os.getenv("id")
    CLIENT_SECRET = os.getenv("secret")
    
    #2. Request
    body_params = {"grant_type":"client_credentials"}
    url = "https://accounts.spotify.com/api/token"
    response = requests.post(url, data=body_params, auth=(CLIENT_ID,CLIENT_SECRET))
    
    try:
        token = response.json()["access_token"]
        return token

    except:
        print("The request did not go through: wrong credentials!")

# %%
token  = spotifyToken()
headers = {"Authorization":f"Bearer {token}"}

# %%
def save_token (CLIENT_ID, CLIENT_SECRET):
    command = f"""echo "CLIENT_ID='{CLIENT_ID}'\nCLIENT_SECRET='{CLIENT_SECRET}'" > .env"""
    os.system(command)

# %%
url_base = "https://api.spotify.com/v1/playlists/"
playlist_url = 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M?si=b705194596334305'

# %%
def playlist_id (playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]

# %%
top_hits_id = playlist_id(playlist_url)

# %%
top_hits_query = url_base + top_hits_id
top_hits_query
# Out:
# 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M'

# %%
top_hits_response = requests.get(top_hits_query, headers=headers).json()

# %%
top_hits_response
# Out:
# {'collaborative': False,
#  'description': 'The Weeknd & Ariana Grande are on top of the Hottest 50!',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#  'followers': {'href': None, 'total': 33110041},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M',
#  'id': '37i9dQZF1DXcBWIGoYBM5M',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab67706f00000003324064f356a27317623abc23',
#    'width': None}],
#  'name': "Today's Top Hits",
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': '#FFFFFF',
#  'public': True,
#  'snapshot_id': 'MTY3NzIxNDgwMCwwMDAwMDAwMGQyNTAyYWM1MTQ2MDkwMmZmM2Y0NzNlM2IzMWZmYjhh',
# ...

# %%
top_hits_response.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
top_hits_response['tracks']['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
top_hits_response['tracks']['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
top_hits_response['tracks']['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
top_hits_response['tracks']['items'][2]['track']['href']
# Out:
# 'https://api.spotify.com/v1/tracks/6AQbmUe0Qwf5PZnt4HmTXv'

# %%
song_href = 'https://api.spotify.com/v1/tracks/6AQbmUe0Qwf5PZnt4HmTXv'
song_response = requests.get(song_href, headers=headers).json()

# %%
song_response['href']
# Out:
# 'https://api.spotify.com/v1/tracks/6AQbmUe0Qwf5PZnt4HmTXv'

# %%
# name of the song
top_hits_response['tracks']['items'][16]['track']['name']
# Out:
# 'Love Again'

# %%
top_hits_response['tracks']['items'][0]['track']['artists']#.keys()
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#   'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#   'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'name': 'The Weeknd',
#   'type': 'artist',
#   'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#   'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#   'id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'name': 'Ariana Grande',
#   'type': 'artist',
#   'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}]

# %%
top_hits_response['tracks']['items'][0]['added_by']['uri']
# Out:
# 'spotify:user:'

# %%
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy as sp

# %%
# track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(todays_top_hits_id)["items"]]

# %%
import lyricsgenius

# %%
from getpass import getpass

# %%
genius_token = getpass()

# %%
genius_token = os.getenv('genius_token') # might need to change it from genius API and replace it into .env in case it expires.

# %%
genius = lyricsgenius.Genius(genius_token)

# %%
example = genius.search_artist("Migos", max_songs=1)
# Out:
# Searching for songs by Migos...
#
# Song 1: "Bad and Boujee"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.

# %%
top_hits_response.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
top_hits_response['tracks']['items'][0]['track']['uri']
# Out:
# 'spotify:track:7oDd86yk8itslrA9HRP2ki'

# %%
artist = genius.search_artist("Migos", max_songs=1)
cancion = "Bad and Boujee"
song = artist.song(cancion)
song.lyrics
# Out:
# Searching for songs by Migos...
#
# Song 1: "Bad and Boujee"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# ...

# %%
print(song.lyrics)
# Out:
# TranslationsPortuguêsРусскийItalianoAzərbaycanca / آذربايجانPolskiTürkçeBad and Boujee Lyrics[Intro: Offset & Future]
# You know, young rich niggas
# You know somethin', we ain't really never had no old money
# We got a whole lotta new money though, hah
# (If Young Metro don't trust you, I'm gon' shoot you)
# Hey
#
# [Chorus: Offset]
# Raindrop (Drip), drop-top (Drop-top)
# Smokin' on cookie in the hotbox (Cookie)
# Fuckin' on your bitch, she a thot, thot (Thot)
# Cookin' up dope in the crockpot (Pot)
# We came from nothin' to somethin', nigga (Hey)
# I don't trust nobody, grip the trigger (Nobody)
# Call up the gang and they come and get ya (Gang)
# Cry me a river, give you a tissue (Hey)
# My bitch is bad and bougie (Bad)
# Cookin' up dope with a Uzi (Blaow)
# My niggas is savage, ruthless (Savage)
# We got 30s and hundred-rounds too (Grrah)
# My bitch is bad and bougie (Bad)
# Cookin' up dope with a Uzi (Dope)
# My niggas is savage, ruthless (Hey)
# ...

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download()
sia = SentimentIntensityAnalyzer()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
sia.polarity_scores(song.lyrics)
# Out:
# {'neg': 0.181, 'neu': 0.734, 'pos': 0.085, 'compound': -0.9993}

# %%
top_hits_response['tracks']['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
tracks = top_hits_response['tracks']['items']

# %%
tracks[0]['track']['uri']
# Out:
# 'spotify:track:7oDd86yk8itslrA9HRP2ki'

# %%
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data4
client_id = os.getenv('id')
client_secret = os.getenv('secret')
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
sp.audio_features(tracks[0]['track']['uri'])
# Out:
# [{'danceability': 0.531,
#   'energy': 0.525,
#   'key': 1,
#   'loudness': -6.5,
#   'mode': 0,
#   'speechiness': 0.0671,
#   'acousticness': 0.232,
#   'instrumentalness': 0,
#   'liveness': 0.441,
#   'valence': 0.502,
#   'tempo': 66.9,
#   'type': 'audio_features',
#   'id': '7oDd86yk8itslrA9HRP2ki',
#   'uri': 'spotify:track:7oDd86yk8itslrA9HRP2ki',
#   'track_href': 'https://api.spotify.com/v1/tracks/7oDd86yk8itslrA9HRP2ki',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7oDd86yk8itslrA9HRP2ki',
#   'duration_ms': 232857,
#   'time_signature': 4}]
